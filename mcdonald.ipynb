# %% [markdown]
# <h1 style="font-family:verdana;"> <center>🍟McDonald's India-EDA</center> </h1>
# <p><center style="color:#159364; font-family:cursive; font-size:20px;">Thanks for visiting my notebook </center></p>
#
# ***
#
# <center><img src='https://media3.giphy.com/media/12cAJO8mkO3hUA/giphy.gif?cid=ecf05e47hle20dtfhl30gju820mwahq2uhkm8bfpt8ig8ox6&ep=v1_gifs_search&rid=giphy.gif&ct=g' height=200px width=300px></center>
#
# # 👋Thanks for Visting my Notebook
# <div class="alert alert-block alert-info"style="background-color:#FFFF00; font-size:20px; font-family:verdana;">
#     📌 Feel free to fork or edit the notebook for your own convenience. If you liked the notebook, consider upvoting. It helps other people discover the notebook as well. Your support inspires me to produce more of these kernel.😊
# </div>
#
# # 🔬Overview
#
# <div style="background-color:#FFFF00; padding: 20px;">
# <p style="font-size:20px; font-family:verdana; line-height: 1.7em">McDonald's is one of the leading food chain in the world, with a massive following.Therefore, it is essential to conduct exploratory data analysis (EDA) and also learn about nutrition Analysis.</p>

# %% [markdown]
# <div style="background-color:red; padding:20px; border-radius:5px;">
#     <h2 style="color:white; font-weight:bold; text-align:center;">Importing Required Libraries</h2>
# </div>

# %% [markdown]
# # 1.Importing Libraries

# %%
#Libraries to work with data
import pandas as pd
import numpy as np

#environment check
import warnings
warnings.filterwarnings('ignore')

#Libraries for plotting
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# %%
df=pd.read_csv('/kaggle/input/mcdonalds-india-menu-nutrition-facts/India_Menu.csv')
df.head()
# Out:
#   Menu Category              Menu Items Per Serve Size  Energy (kCal)  \
# 0  Regular Menu        McVeggie™ Burger          168 g         402.05
# 1  Regular Menu    McAloo Tikki Burger®          146 g         339.52
# 2  Regular Menu  McSpicy™ Paneer Burger          199 g         652.76
# 3  Regular Menu       Spicy Paneer Wrap          250 g         674.68
# 4  Regular Menu     American Veg Burger          177 g         512.17
#
#    Protein (g)  Total fat (g)  Sat Fat (g)  Trans fat (g)  Cholesterols (mg)  \
# 0        10.24          13.83         5.34           0.16               2.49
# 1         8.50          11.31         4.27           0.20               1.47
# 2        20.29          39.45        17.12           0.18              21.85
# 3        20.96          39.10        19.73           0.26              40.93
# 4        15.30          23.45        10.51           0.17              25.24
#
#    Total carbohydrate (g)  Total Sugars (g)  Added Sugars (g)  Sodium (mg)
# ...

# %%
df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(' ','_')

# %% [markdown]
# <div style="background-color:red; padding:20px; border-radius:5px;">
#     <h2 style="color:white; font-weight:bold; text-align:center;">Understanding Data</h2>
# </div>

# %% [markdown]
# # 2.Understanding Data

# %%
df.isnull().sum()
# Out:
# menu_category             0
# menu_items                0
# per_serve_size            0
# energy_(kcal)             0
# protein_(g)               0
# total_fat_(g)             0
# sat_fat_(g)               0
# trans_fat_(g)             0
# cholesterols_(mg)         0
# total_carbohydrate_(g)    0
# total_sugars_(g)          0
# added_sugars_(g)          0
# sodium_(mg)               1
# dtype: int64

# %%
df=df.fillna(0)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#        energy_(kcal)  protein_(g)  total_fat_(g)  sat_fat_(g)  trans_fat_(g)  \
# count     141.000000   141.000000     141.000000   141.000000     141.000000
# mean      244.635461     7.493546       9.991702     4.997589       0.687163
# std       185.554837     8.336863      10.339511     4.900451       6.326136
# min         0.000000     0.000000       0.000000     0.000000       0.000000
# 25%       116.360000     0.650000       0.460000     0.280000       0.060000
# 50%       219.360000     4.790000       7.770000     4.270000       0.150000
# 75%       339.520000    10.880000      14.160000     7.280000       0.220000
# max       834.360000    39.470000      45.180000    20.460000      75.260000
#
#        cholesterols_(mg)  total_carbohydrate_(g)  total_sugars_(g)  \
# count         141.000000              141.000000        141.000000
# mean           26.350071               31.190284         15.464894
# std            50.334200               20.602044         15.690202
# ...

# %%
df.dtypes
# Out:
# menu_category              object
# menu_items                 object
# per_serve_size             object
# energy_(kcal)             float64
# protein_(g)               float64
# total_fat_(g)             float64
# sat_fat_(g)               float64
# trans_fat_(g)             float64
# cholesterols_(mg)         float64
# total_carbohydrate_(g)    float64
# total_sugars_(g)          float64
# added_sugars_(g)          float64
# sodium_(mg)               float64
# dtype: object

# %% [markdown]
# <div style="background-color:red; padding:20px; border-radius:5px;">
#     <h2 style="color:white; font-weight:bold; text-align:center;">Correlation Matrix</h2>
# </div>

# %% [markdown]
# # 3. Correlation Matrix

# %%
#Credits https://www.kaggle.com/code/prena0808/exploratory-data-analysis-for-nutrition-value

corr = df.drop(['menu_category', 'menu_items'], axis=1).corr() 
plt.figure(figsize=(8, 8))

sns.heatmap(corr[(corr >= 0.5) | (corr <= -0.4)], 
            cmap='viridis', vmax=1.0, vmin=-1.0, 
            linewidths=0.1,annot=True, 
            annot_kws={"size": 8}, square=True)
# Out:
# <AxesSubplot: >

# %% [markdown]
# <div style="background-color:red; padding:20px; border-radius:5px;">
#     <h2 style="color:white; font-weight:bold; text-align:center;">PairPlot</h2>
# </div>

# %% [markdown]
# # 4. PairPlot

# %%
sns.pairplot(df,hue='menu_category')

# %% [markdown]
# <div style="background-color:red; padding:20px; border-radius:5px;">
#     <h2 style="color:white; font-weight:bold; text-align:center;">Unhealthy Menu Options-measured in terms of total fat content, total sugar, cholesterol, or sodium</h2>
# </div>

# %% [markdown]
# # 5.Unhealthy Menu Options-measured in terms of total fat content, total sugar, cholesterol, or sodium

# %% [markdown]
# ##### Source : https://www.healthline.com/nutrition/sodium-per-day

# %% [markdown]
# ![image.png](attachment:5192a43a-d016-4c7f-85b1-5ffe32ed7fc0.png)

# %% [markdown]
# #### Checking if any dish has sodium content greater than or equal to 2300mg

# %%
df[df['sodium_(mg)']>=2300][['menu_category', 'menu_items', 'per_serve_size', 'energy_(kcal)',
       'protein_(g)', 'total_fat_(g)',
       'cholesterols_(mg)', 'total_carbohydrate_(g)', 'total_sugars_(g)', 'sodium_(mg)']]
# Out:
#    menu_category                                  menu_items per_serve_size  \
# 18  Regular Menu  Ghee Rice with Mc Spicy Fried Chicken 1 pc          325 g
#
#     energy_(kcal)  protein_(g)  total_fat_(g)  cholesterols_(mg)  \
# 18          720.3        26.91           29.2              31.32
#
#     total_carbohydrate_(g)  total_sugars_(g)  sodium_(mg)
# 18                   77.47              3.28      2399.49

# %% [markdown]
# #### Assuming a person consumes one meal from McDonald then sodium content of more than 1725mg which is 3 fourth of the limit per day could be dangerous.
# #### Checking for food items with sodium content more than 1725mg

# %%
df[df['sodium_(mg)'].apply(lambda x: 1725 <= x < 2300)][['menu_category', 'menu_items', 'per_serve_size', 'energy_(kcal)',
       'protein_(g)', 'total_fat_(g)',
       'cholesterols_(mg)', 'total_carbohydrate_(g)', 'total_sugars_(g)', 'sodium_(mg)']]
# Out:
#     menu_category                               menu_items per_serve_size  \
# 12   Regular Menu                     Chicken Maharaja Mac          296 g
# 107  Gourmet Menu               Chicken Cheese Lava Burger          307 g
# 108  Gourmet Menu  Chunky Chipotle American Burger Chicken          301 g
#
#      energy_(kcal)  protein_(g)  total_fat_(g)  cholesterols_(mg)  \
# 12          689.12        34.00          36.69              81.49
# 107         834.36        27.37          45.18              73.11
# 108         641.36        39.47          31.51             110.37
#
#      total_carbohydrate_(g)  total_sugars_(g)  sodium_(mg)
# 12                    55.39              8.92      1854.71
# 107                   76.03             16.75      1745.04
# 108                   46.24              9.16      1906.27

# %%
# Create the boxplot
plt.figure(figsize = (12, 6))

ax = sns.boxplot(x='menu_category', y='sodium_(mg)',data=df,flierprops={'markerfacecolor': 'red', 'marker': 'o'})

# Rotate x-axis labels
plt.xticks(rotation=45)

# Set title
plt.title('Total Sodium Mark')

# Set background color
fig = plt.gcf()
fig.set_facecolor('black')
ax.set_facecolor('black')

# Set tick colors
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

# Set label colors
ax.xaxis.label.set_color('white')
ax.yaxis.label.set_color('white')

# Set grid color
#ax.yaxis.grid(color='white')

# Display the plot
plt.show()

# %% [markdown]
# # 6.Plotting FAT-SUGAR-CHOLESTEROLS

# %% [markdown]
# <div style="background-color:red; padding:20px; border-radius:5px;">
#     <h2 style="color:white; font-weight:bold; text-align:center;">Plotting FAT-SUGAR-CHOLESTEROLS</h2>
# </div>

# %%
fig=px.scatter(df,x='total_fat_(g)',y='total_sugars_(g)',size='cholesterols_(mg)',
               color='menu_category',hover_name='menu_items',template='plotly_dark')
fig.update_layout(title_text='FAT-SUGAR-CHOLESTEROLS',template='plotly_dark')
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.20.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %% [markdown]
# ## Observations
# #### 1.McCafe and Beverages menu items have high total sugar content
# #### 2.Regular,Breakfast and Gourmet menu items have low total sugar content
# #### 3.Regular Menu items have high fat content
# #### 3.Chocolate oreo Frapper(Breakast menu) has highest total sugar content of 55.14g
# #### 4.Chicken cheese lava burger(Gourment menu) has highest total fat content of 45.18g
# #### 5.McSpicy Premium Chicken Burger(Gourment menu) has the highest cholesterol content of 302.61mg

# %% [markdown]
# ![image.png](attachment:583a8221-9840-48e3-9007-ab2dd6b9c512.png)

# %% [markdown]
# <div style="background-color:red; padding:20px; border-radius:5px;">
#     <h2 style="color:white; font-weight:bold; text-align:center;">Plotting Macro Nutrients</h2>
# </div>

# %% [markdown]
# # 7.Plotting Macro Nutrients

# %%
fig=px.scatter(df,x='protein_(g)',y='total_carbohydrate_(g)',size='total_fat_(g)',
               color='menu_category',hover_data='energy_(kcal)',hover_name='menu_items',template='plotly_dark')
fig.update_layout(title_text='PROTEINS-CARBOHYDRATES-FAT',template='plotly_dark')
fig.show()
# Out:
# <div>                            <div id="b1ece7da-fdba-4b77-8974-f2e74196ff54" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b1ece7da-fdba-4b77-8974-f2e74196ff54")) {                    Plotly.newPlot(                        "b1ece7da-fdba-4b77-8974-f2e74196ff54",                        [{"customdata":[[402.05],[339.52],[652.76],[674.68],[512.17],[832.67],[356.09],[228.21],[400.8],[348.11],[451.92],[567.19],[689.12],[446.95],[357.05],[230.95],[290.42],[282.98],[720.3],[248.76],[169.68],[254.52],[381.77],[164.44],[246.65],[411.09],[224.59],[317.92],[449.17],[204.65],[280.05],[387.76],[6.8],[35.8],[341.68],[329.29]],"hovertemplate":"<b>%{hovertext}</b><br><br>menu_category=Regular Menu<br>protein_(g)=%{x}<br>total_carbohydrate_(g)=%{y}<br>total_fat
# ...

# %% [markdown]
# ## Observation
# #### 1.Condiments Menu items don't have significant distribution of nutrients with an average energy of almost 47 kcal
# #### 2.Beverages Menu items don't contain high amount of nutrients with an average energy of almost 143 kcal which is roughly 3 times more than Condiment Menu
# #### 3.McCafe Menu items aren't high on proteins but a few items contain fair amount of carbohydrates and fat and average energy of almost 184 kcal which is roughly 4 times more than that of condiments Menu
# #### 4.Gourmet Menu items are rich of macro nutrients especially have high fat content due to which they have an average energy of 543 kcal
# #### 5.McCafe Menu items are not rich with Proteins but fair amount of carbohydates(avg carbs of 29g) and average energy of 184 kcal
# #### 6.Regular Menu items are rich with macro nutrients and energy with an average of 368 kcal
#
# ## Dishes
# #### 1.Chicken cheese lava burger(Gourmet Menu) has the highest energy of 834.36 but also has highest fat content of 45.18
# #### 2.Chunky chipotle American burger chicken(Gourment Menu) has the highest protein content of 39.47g
# #### 3.Veg Maharaj Mac(Regular Menu) has the highest carbohydrates content of 93.84g

# %% [markdown]
# <div style="background-color:red; padding:20px; border-radius:5px;">
#     <h2 style="color:white; font-weight:bold; text-align:center;">How is Energy for an item calculated?</h2>
# </div>

# %% [markdown]
# # 8.How is Energy for an item calculated ?

# %% [markdown]
# ## Energy is calculated by

# %% [markdown]
# ![image.png](attachment:73525918-333e-4302-a65b-eb0cf1f1821a.png)

# %% [markdown]
# <div style="background-color:red; padding:20px; border-radius:5px;">
#     <h2 style="color:white; font-weight:bold; text-align:center;">Energy calculation of an item example</h2>
# </div>

# %% [markdown]
# # 8.1 Energy calculation of an item example

# %% [markdown]
# ## Using the formula to calculate the energy for the McVeggie™ Burger(Regular Menu)

# %% [markdown]
# ![image.png](attachment:3972eaa8-0b8c-4b70-9d1a-51b4bfcfe1d6.png)

# %% [markdown]
# #### Factors that can contribute to the gap between the estimated value and the true value of 402.05 kcal include:
#
# #### 1.Measurement accuracy: There can be slight variations in the accuracy of measuring the exact amounts of macronutrients in a food item, leading to small discrepancies in the calculated energy content.
#
# #### 2.Food processing and cooking methods: Food processing techniques and cooking methods can affect the availability and digestibility of nutrients, which can impact the actual energy content of the dish.
#
# #### 3.Nutrient interactions: The presence of certain nutrients or food components in combination can affect the absorption and utilization of energy from the macronutrients, potentially altering the overall energy content.
#
# #### 4.Labeling inaccuracies: Nutritional information provided on food labels or in nutritional databases might not always be completely accurate, as there can be errors in data entry or variations in the composition of different batches or brands of the same food.

# %% [markdown]
# <div style="background-color:red; padding:20px; border-radius:5px;">
#     <h2 style="color:white; font-weight:bold; text-align:center;">Plotting Categories</h2>
# </div>

# %% [markdown]
# # 9.Plotting categories

# %%
plt.title('Distribution of Menu')
df.groupby('menu_category')['menu_category'].count().plot.pie(figsize=(8,8),autopct="%1.1f%%")
# Out:
# <AxesSubplot: title={'center': 'Distribution of Menu'}, ylabel='menu_category'>

# %%
categories = df['menu_category'].value_counts()

plt.figure(figsize=(15,8))
fig=px.bar(categories,title='Number of items in categories',template='plotly_dark')
fig.update_traces(marker_color='#FFFF33')
fig.show()
# Out:
# <div>                            <div id="6898bacd-1dff-4fa9-ac76-107e535b57e3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6898bacd-1dff-4fa9-ac76-107e535b57e3")) {                    Plotly.newPlot(                        "6898bacd-1dff-4fa9-ac76-107e535b57e3",                        [{"alignmentgroup":"True","hovertemplate":"variable=menu_category<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"menu_category","marker":{"color":"#FFFF33","pattern":{"shape":""}},"name":"menu_category","offsetgroup":"menu_category","orientation":"v","showlegend":true,"textposition":"auto","x":["McCafe Menu","Regular Menu","Beverages Menu","Breakfast Menu","Gourmet Menu","Condiments Menu","Desserts Menu"],"xaxis":"x","y":[51,36,17,15,11,9,2],"yaxis":"y
# ...

# %%
org_df=df.copy()

# %%
#credits https://www.kaggle.com/code/manishwahale/mcd-india-menu-nutrition-analysis
df_snacks = df[df['per_serve_size'].str.contains('g')]
df_snacks['per_serve_size'] = df_snacks['per_serve_size'].str.replace(' g', '')
df_snacks['per_serve_size'] = df_snacks['per_serve_size'].astype('float64')

df_drinks = df[df['per_serve_size'].str.contains('ml')]
df_drinks['per_serve_size'] = df_drinks['per_serve_size'].str.replace(' ml', '')
df_drinks['per_serve_size'] = df_drinks['per_serve_size'].astype('float64')

# %%
#Resetting Index
df_snacks.index = np.arange(1, len(df_snacks) + 1)
df_drinks.index = np.arange(1, len(df_drinks) + 1)

# %% [markdown]
# <div style="background-color:red; padding:20px; border-radius:5px;">
#     <h2 style="color:white; font-weight:bold; text-align:center;">Snacks vs Drinks</h2>
# </div>

# %% [markdown]
# # 10. Snacks vs Drinks

# %%
#Credits https://www.kaggle.com/code/manishwahale/mcd-india-menu-nutrition-analysis
fig = px.bar(x =['snacks', 'drinks'] ,y=[df_snacks.shape[0], df_drinks.shape[0]],
             color=['snacks', 'drinks'],color_discrete_map={'snacks':'rgb(195,125,55)','drinks':'rgb(255,180,0)'},title='Snacks vs Drinks')
fig.update_xaxes(title_text=None)
fig.update_yaxes(title_text='Count')
# Out:
# <div>                            <div id="979766d1-5847-4276-b3ad-13d28ef19819" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("979766d1-5847-4276-b3ad-13d28ef19819")) {                    Plotly.newPlot(                        "979766d1-5847-4276-b3ad-13d28ef19819",                        [{"alignmentgroup":"True","hovertemplate":"color=snacks<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"snacks","marker":{"color":"rgb(195,125,55)","pattern":{"shape":""}},"name":"snacks","offsetgroup":"snacks","orientation":"v","showlegend":true,"textposition":"auto","x":["snacks"],"xaxis":"x","y":[73],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=drinks<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"drinks","marker":{"color":"r
# ...

# %%
df_snacks['menu_items'] = df_snacks['menu_items'].str.lower()
df_nonveg = df[(df['menu_items'].str.contains('chicken')) | 
               (df_snacks['menu_items'].str.contains('fish')) |
               (df_snacks['menu_items'].str.contains(' egg')) |
               (df_snacks['menu_items'].str.contains('sausage'))] 

df_veg = pd.concat([df, df_nonveg]).drop_duplicates(keep=False)

# %% [markdown]
# ***
# <div style="display: flex;
#             align-items: center;
#             justify-content: center;
#             border-radius: 5px;
#             background-color: #5642C5;
#             font-size: 110%;
#             font-family: Verdana;
#             letter-spacing: 0.5px;
#             color: white;">
#     <p style="padding: 10px;">
#         Thanks for viewing my work. If you like it, consider sharing it with others or give feedback to improve the notebook. Have a beautiful day.
#     </p>
# </div>
#
# <center><img src='https://media2.giphy.com/media/9cPhbctxoVgJIIGKDx/200w.webp?cid=ecf05e47jo5gmccyqtlssb7wb2g8tbr1t4xrt6eo7hdzrd0e&ep=v1_gifs_search&rid=200w.webp&ct=g'
#      height=30px width=160px font=50px /></center>
